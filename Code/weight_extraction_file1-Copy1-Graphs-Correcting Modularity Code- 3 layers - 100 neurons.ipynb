# %%
import pandas as pd 
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np 
from statistics import mean
from sklearn.preprocessing import MinMaxScaler 
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout
import seaborn as sns
import networkx as nx

# %%
df = pd.DataFrame()
f = yf.download(tickers = "RELIANCE.NS",
                       start = '2022-01-01',
                       end = '2022-06-01',)

#df = f[[("Adj Close", s) for s in list_of_stocks]]
df = f[["Adj Close"]]
#df.columns = df.columns.droplevel(level=0)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#               Adj Close
# Date
# 2022-01-03  2396.634521
# 2022-01-04  2450.721680
# 2022-01-05  2462.187012
# 2022-01-06  2409.246338
# 2022-01-07  2428.687988
# ...                 ...
# 2022-05-25  2604.159668
# 2022-05-26  2579.334473
# 2022-05-27  2567.370361
# 2022-05-30  2656.801025
# 2022-05-31  2624.747559
#
# [101 rows x 1 columns]

# %%
#convert to numpy array for neurl network to take input 

#print(type(df))
training_set = f.iloc[:,4:5].values
#print(type(df))

# %%
plt.figure(figsize=(12,10))
plt.plot(df)
plt.xlabel("Date", fontsize = 20)
plt.ylabel("Price", fontsize = 20)
plt.title("Adj Close Price of Reliance Stock", fontsize = 20)
plt.grid(True)
plt.show()

# %%
scaler = MinMaxScaler(feature_range = (0,1))
scaler
training_set_scaled = scaler.fit_transform(training_set)

# %%
#Lag = 15 -( 3 weeks )
#Train the model on 15 day data
x_train_a = []
y_train_a = []
for i in range(15, len(training_set_scaled)):
    x_train_a.append(training_set_scaled[i-15: i, 0])
    y_train_a.append(training_set_scaled[i])

x_train_a, y_train_a = np.array(x_train_a), np.array(y_train_a)

# %%
N = len(y_train_a)

# %%
N #Total number of inputs
# Out:
# 86

# %%
x_train_a.shape
# Out:
# (86, 15)

# %%
 ## make model 
# instntiate model
my_model = Sequential()

# add layers 

#layer 1
my_model.add(SimpleRNN(units = 100, return_sequences = True, activation = "relu", input_shape = (x_train_a.shape[1] ,1)))
my_model.add(Dropout(rate = 0.2))

#layer 2
my_model.add(SimpleRNN(units = 100, return_sequences = True, activation = "relu"))
my_model.add(Dropout(rate = 0.2))


#layer 3
my_model.add(SimpleRNN(units = 100, return_sequences = True, activation = "relu"))
my_model.add(Dropout(rate = 0.2))

#layer 4
my_model.add(SimpleRNN(units = 100, return_sequences = False, activation = "relu"))
my_model.add(Dropout(rate = 0.2))

#output layer 
my_model.add(Dense(units = 1))

## compile model 
my_model.compile(optimizer = "adam", loss = "mean_squared_error")

# %%
my_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 15, 100)           10200
#
#  dropout (Dropout)           (None, 15, 100)           0
#
#  simple_rnn_1 (SimpleRNN)    (None, 15, 100)           20100
#
#  dropout_1 (Dropout)         (None, 15, 100)           0
#
#  simple_rnn_2 (SimpleRNN)    (None, 15, 100)           20100
#
#  dropout_2 (Dropout)         (None, 15, 100)           0
#
#  simple_rnn_3 (SimpleRNN)    (None, 100)               20100
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 70,601
# Trainable params: 70,601
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Fit Model

# %%
# METHOD 1: ONLY SAVES 1 LAYER, ALL WEIGHTS 
# use callback function to get weights after every epoch 
from keras.callbacks import Callback

class CollectWeightCallback(Callback):
    def __init__(self, layer_index):
        super(CollectWeightCallback, self).__init__()
        self.layer_index = layer_index
        self.weights = []

    def on_epoch_end(self, epoch, logs=None):
        layer = self.model.layers[self.layer_index]
        self.weights.append(layer.get_weights()[0]) # [0] - get weight only, no biases

# %%
numEpochs = 100
numBatch = 20

# %%
cbk0 = CollectWeightCallback(layer_index=0) # 0 = 1st layer 
cbk2 = CollectWeightCallback(layer_index=2) # 2 = 2nd layer or 1st dense layer 
cbk4 = CollectWeightCallback(layer_index=4) # 4 = 3rd layer or 2nd dense layer 
cbk6 = CollectWeightCallback(layer_index=6) # 6 = 4th layer or 3rd dense layer 
cbk8 = CollectWeightCallback(layer_index=8) # 8 = last layer 
my_model.fit(x_train_a, y_train_a, epochs = numEpochs, callbacks=[cbk0, cbk2, cbk4, cbk6, cbk8], batch_size = numBatch)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 7s 28ms/step - loss: 0.2000
# Epoch 2/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0986
# Epoch 3/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0599
# Epoch 4/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0354
# Epoch 5/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0340
# Epoch 6/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0272
# Epoch 7/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0220
# Epoch 8/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0305
# Epoch 9/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0246
# Epoch 10/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0265
# Epoch 11/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0225
# Epoch 12/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0214
# Epoch 13/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0242
# Epoch 14/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0261
# Epoch 15/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0192
# Epoch 16/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0188
# Epoch 17/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0228
# Epoch 18/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0186
# Epoch 19/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0165
# Epoch 20/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0213
# Epoch 21/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0188
# Epoch 22/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0206
# Epoch 23/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0197
# Epoch 24/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0202
# Epoch 25/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0172
# Epoch 26/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0155
# Epoch 27/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0140
# Epoch 28/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0162
# Epoch 29/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0142
# Epoch 30/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0129
# Epoch 31/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0169
# Epoch 32/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0147
# Epoch 33/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0133
# Epoch 34/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0156
# Epoch 35/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0169
# Epoch 36/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0122
# Epoch 37/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0157
# Epoch 38/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0153
# Epoch 39/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0185
# Epoch 40/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0105
# Epoch 41/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0146
# Epoch 42/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0173
# Epoch 43/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0141
# Epoch 44/100
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0100
# Epoch 45/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0101
# Epoch 46/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0131
# Epoch 47/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0140
# Epoch 48/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0132
# Epoch 49/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0112
# Epoch 50/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0093
# Epoch 51/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0131
# Epoch 52/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0117
# Epoch 53/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0102
# Epoch 54/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0114
# Epoch 55/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0100
# Epoch 56/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0124
# Epoch 57/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0104
# Epoch 58/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0138
# Epoch 59/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0126
# Epoch 60/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0125
# Epoch 61/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0100
# Epoch 62/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0139
# Epoch 63/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0142
# Epoch 64/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0125
# Epoch 65/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0108
# Epoch 66/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0088
# Epoch 67/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0109
# Epoch 68/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0106
# Epoch 69/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0113
# Epoch 70/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0110
# Epoch 71/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0128
# Epoch 72/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0093
# Epoch 73/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0083
# Epoch 74/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0106
# Epoch 75/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0095
# Epoch 76/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0086
# Epoch 77/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0098
# Epoch 78/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0080
# Epoch 79/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0112
# Epoch 80/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0121
# Epoch 81/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0133
# Epoch 82/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0102
# Epoch 83/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0096
# Epoch 84/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0115
# Epoch 85/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0108
# Epoch 86/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0086
# Epoch 87/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0097
# Epoch 88/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0085
# Epoch 89/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0093
# Epoch 90/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0077
# Epoch 91/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0111
# Epoch 92/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0106
# Epoch 93/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0088
# Epoch 94/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0072
# Epoch 95/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0064
# Epoch 96/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0069
# Epoch 97/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0091
# Epoch 98/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0083
# Epoch 99/100
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0067
# Epoch 100/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0074

# %% [markdown]
# ## Get Weights

# %% [markdown]
# Make Indices

# %%
m = 100 # no. of neurons in a hidden layer 
p = 100
index_neuron = [] 
weights_neuron = []
for i in range(100):
    index_neuron.append("Neuron " + str(i+1))
    weights_neuron.append("W" + str(i+1))

# %%
n = 0 # weights for n+1th epoch
# hidden layer 1
df01 = pd.DataFrame(cbk2.weights[n], index = index_neuron , columns = weights_neuron)
df01 = df01.transpose()
# hidden layer 2
df02 = pd.DataFrame(cbk4.weights[n], index = index_neuron , columns = weights_neuron)
df02 = df02.transpose()
# hidden layer 3
df03 = pd.DataFrame(cbk6.weights[n], index = index_neuron , columns = weights_neuron)
df03 = df03.transpose()

# %% [markdown]
# #### Checking correlation among different layers

# %%
new_df01 = [df01, df02, df03]
df_layer = pd.concat(new_df01, axis = 1, keys = ["L1", "L2", "L3"])

# %%
cor_mat01 = df01.corr() # correlations
f, ax = plt.subplots(figsize = (20,20)) # figure
cmap = sns.color_palette("vlag", as_cmap = True) # colour 
sns.heatmap(
    cor_mat01, # correlations
    cmap = cmap, # colour 
    #annot = True, # show values in cells? 
    vmax = 0.7, # max value on legend, >= .7 will be same color
    vmin = -0.7, # min value on the legend, <= .7 will be same color 
    square = True, # Force cells to be square 
    linewidth = .5, # width of lines that divide cells 
    cbar_kws = {"shrink": .5}
)
plt.xticks(range(df01.select_dtypes(['number']).shape[1]), df01.select_dtypes(['number']).columns, fontsize=14, rotation=90)
plt.yticks(range(df01.select_dtypes(['number']).shape[1]), df01.select_dtypes(['number']).columns, fontsize=14)
plt.title('Correlation Matrix - Epoch 1 Layer 1', fontsize=20);

# %%
n = 99 # weights for n+1th epoch
# hidden layer 1
df99 = pd.DataFrame(cbk2.weights[n], index = index_neuron , columns = weights_neuron)
df99 = df99.transpose()

# %%
cor_mat = df99.corr() # correlations
f, ax = plt.subplots(figsize = (20,20)) # figure
cmap = sns.color_palette("vlag", as_cmap = True) # colour 
sns.heatmap(
    cor_mat, # correlations
    cmap = cmap, # colour 
    #annot = True, # show values in cells? 
    vmax = 0.3, # max value on legend, >= .7 will be same color
    vmin = -0.3, # min value on the legend, <= .7 will be same color 
    square = True, # Force cells to be square 
    linewidth = .5, # width of lines that divide cells 
    cbar_kws = {"shrink": .5}
)
plt.xticks(range(df99.select_dtypes(['number']).shape[1]), df99.select_dtypes(['number']).columns, fontsize=14, rotation=90)
plt.yticks(range(df99.select_dtypes(['number']).shape[1]), df99.select_dtypes(['number']).columns, fontsize=14)
plt.title('Correlation Matrix - Epoch 100 Layer 1', fontsize=20);

# %% [markdown]
# Graph of Neurons in Layer 1 Epoch 1

# %% [markdown]
# ### Graphs

# %%
# make an edge list 

# converts lower triangular matrix to 0
cor_mat= cor_mat.mask(np.tril(np.ones(cor_mat.shape)).astype(np.bool_), 0) 

# creating edge list 
links = cor_mat.stack().reset_index()
links.columns = ['Neuron A', 'Neuron B', 'Value'] 
#drop the rows with 0 in Value 
rows_zero = links.loc[links['Value'] == 0.0]
links = links.drop(rows_zero.index)

# save values with correlation more than 0.2
links_filtered=links.loc[ (links['Value'] > abs(0.2)) ]

# make the graph 
G=nx.from_pandas_edgelist(links_filtered, 'Neuron A', 'Neuron B')
pos = nx.spring_layout(G)
#pos = nx.spectral_layout(G) 
# spectral layout helps us see how the community structure or other forms of structure in the graph. 
# It uses eigen vectors and eigen values to position the nodes. 

# plot the graph 
plt.figure(figsize=(8,6), dpi=200)
nx.draw(G, pos, with_labels=True, node_color='orange', width = 2, edge_color='black', linewidths=10, font_size=10, node_size = 200)
plt.title('Epoch 100 Layer 1 corr>0.2')
plt.show()

# %%
# make network grah
def make_graph(corr_mat, correlation_value):
    
    # make a for loop for graph layout
    p = correlation_value
    cor_mat = corr_mat
    # make an edge list 

    # converts lower triangular matrix to 0
    cor_mat= cor_mat.mask(np.tril(np.ones(cor_mat.shape)).astype(np.bool_), 0) 

    # creating edge list 
    links = cor_mat.stack().reset_index()
    links.columns = ['Neuron A', 'Neuron B', 'Value'] 
    #drop the rows with 0 in Value 
    rows_zero = links.loc[links['Value'] == 0.0]
    links = links.drop(rows_zero.index)

    # save values with correlation more than 0.2
    links_filtered=links.loc[ (links['Value'] > abs(p)) ]

    # make the graph 
    G=nx.from_pandas_edgelist(links_filtered, 'Neuron A', 'Neuron B')
    pos = nx.spring_layout(G)
    #pos = nx.spectral_layout(G) 
    # spectral layout helps us see how the community structure or other forms of structure in the graph. 
    # It uses eigen vectors and eigen values to position the nodes. 

    # plot the graph 
    plt.figure(figsize=(8,6), dpi=200)
    nx.draw(G, pos, with_labels=True, node_color='orange', width = 2, edge_color='black', linewidths=10, font_size=10, node_size = 200)
    plt.title('Epoch 100 Layer 1 corr>0.2')
    plt.show()

# %%
make_graph(cor_mat, 0.2)

# %%
from networkx.algorithms.community.centrality import girvan_newman 
communities = girvan_newman(G)
node_groups = []
for com in (communities):
    node_groups.append(list(com))

#print(node_groups)

color_map = []
for node in G:
    if node in node_groups[0]:
        color_map.append("green")
    elif node in node_groups[1]:
        color_map.append("red")
    else:
        color_map.append("orange")
nx.draw(G, node_color=color_map, with_labels=True)
plt.show()

# %% [markdown]
# ## Community Detection using Louvain - highest modularity

# %%
import community.community_louvain as community_louvain
# Detect communities using Louvain algorithm
partition = community_louvain.best_partition(G)

# Print the community membership of each node
#for node, community_id in partition.items():
#    print("Node", node, "belongs to community", community_id)

modularity = community_louvain.modularity(partition, G)
# print(modularity)

# %%
partition
# Out:
# {'Neuron 1': 0,
#  'Neuron 32': 0,
#  'Neuron 79': 0,
#  'Neuron 2': 1,
#  'Neuron 43': 1,
#  'Neuron 3': 1,
#  'Neuron 15': 1,
#  'Neuron 4': 2,
#  'Neuron 50': 2,
#  'Neuron 59': 2,
#  'Neuron 63': 1,
#  'Neuron 75': 2,
#  'Neuron 5': 1,
#  'Neuron 55': 1,
#  'Neuron 6': 3,
#  'Neuron 44': 3,
#  'Neuron 70': 4,
#  'Neuron 7': 4,
#  'Neuron 26': 4,
#  'Neuron 8': 5,
#  'Neuron 65': 5,
#  'Neuron 82': 5,
#  'Neuron 9': 6,
#  'Neuron 34': 6,
#  'Neuron 49': 7,
#  'Neuron 11': 3,
#  'Neuron 22': 3,
#  'Neuron 51': 3,
#  'Neuron 12': 7,
#  'Neuron 47': 1,
#  'Neuron 52': 7,
#  'Neuron 54': 7,
#  'Neuron 67': 7,
#  'Neuron 14': 9,
#  'Neuron 84': 9,
#  'Neuron 29': 1,
#  'Neuron 41': 0,
#  'Neuron 16': 2,
#  'Neuron 17': 5,
#  'Neuron 37': 5,
#  'Neuron 40': 4,
#  'Neuron 53': 5,
#  'Neuron 64': 6,
#  'Neuron 68': 5,
#  'Neuron 18': 10,
#  'Neuron 48': 10,
#  'Neuron 83': 10,
#  'Neuron 19': 6,
#  'Neuron 20': 3,
#  'Neuron 73': 3,
#  'Neuron 76': 11,
#  'Neuron 88': 3,
#  'Neuron 94': 0,
#  'Neuron 21': 7,
#  'Neuron 86': 7,
#  'Neuron 97': 7,
#  'Neuron 24': 7,
#  'Neuron 25': 0,
#  'Neuron 74': 3,
#  'Neuron 100': 0,
#  'Neuron 96': 4,
#  'Neuron 27': 1,
#  'Neuron 56': 8,
#  'Neuron 28': 0,
#  'Neuron 30': 9,
#  'Neuron 85': 9,
#  'Neuron 92': 9,
#  'Neuron 95': 6,
#  'Neuron 98': 5,
#  'Neuron 31': 8,
#  'Neuron 45': 8,
#  'Neuron 81': 8,
#  'Neuron 33': 11,
#  'Neuron 39': 11,
#  'Neuron 57': 11,
#  'Neuron 60': 6,
#  'Neuron 35': 6,
#  'Neuron 36': 3,
#  'Neuron 38': 11,
#  'Neuron 71': 11,
#  'Neuron 72': 3,
#  'Neuron 66': 4,
#  'Neuron 93': 4,
#  'Neuron 87': 0,
#  'Neuron 42': 11,
#  'Neuron 89': 8,
#  'Neuron 61': 7,
#  'Neuron 91': 2,
#  'Neuron 58': 8,
#  'Neuron 62': 4,
#  'Neuron 69': 3,
#  'Neuron 77': 5,
#  'Neuron 99': 0,
#  'Neuron 90': 7}

# %%
# Prints the list of communities
new_dict = {}
for key, value in partition.items():
    new_dict.setdefault(value, []).append(key)

# Convert the dictionary of lists into a list of lists
result = list(new_dict.values())

# %%
len(result)
# Out:
# 12

# %% [markdown]
# ### Modularity - Using Louvain Algorithm

# %% [markdown]
# # The Modularity Function - Change over time - Layer 1

# %%
# Correlation matrix for every epoch of Hidden Layer 1
corr_mat_epoch = []
for n in range(numEpochs):
    df = pd.DataFrame(cbk2.weights[n], index = index_neuron , columns = weights_neuron)
    df = df.transpose() 
    df = df.corr()
    df = df.mask(np.tril(np.ones(df.shape)).astype(np.bool_), 0) 
    corr_mat_epoch.append(df)

# %%
# finding modularity for each matrix 
modularity_layer1 = []
communities_layer1 = []
for n in range(numEpochs):
    cor_mat = corr_mat_epoch[n]
        # creating edge list 
    links = cor_mat.stack().reset_index()
    links.columns = ['Neuron A', 'Neuron B', 'Value'] 
    # drop the rows with 0 in Value 
    rows_zero = links.loc[links['Value'] == 0.0]
    links = links.drop(rows_zero.index)

    # save values with correlation more than 0.2
    links_filtered=links.loc[ (links['Value'] > abs(0.2)) ]

    # make the graph 
    G=nx.from_pandas_edgelist(links_filtered, 'Neuron A', 'Neuron B')
    pos = nx.spring_layout(G) 

    # calculate modularity 
    # Detect communities using Louvain algorithm
    partition = community_louvain.best_partition(G)
    
    # list of communities
    new_dict = {}
    for key, value in partition.items():
        new_dict.setdefault(value, []).append(key)
    # Convert the dictionary of lists into a list of lists
    result = list(new_dict.values())
    
    communities_layer1.append(len(result))

    modularity = community_louvain.modularity(partition, G)
    
    modularity_layer1.append(modularity)

# %%
plt.figure(figsize=(12,10))
plt.plot(modularity_layer1)
plt.xlabel("Epoch", fontsize = 20)
plt.ylabel("Modularity", fontsize = 20)
plt.title("Modularity of Layer 1", fontsize = 20)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.plot(communities_layer1)
plt.xlabel("Epoch", fontsize = 20)
plt.ylabel("Communities", fontsize = 20)
plt.title("Communities in Layer 1", fontsize = 20)
plt.grid(True)
plt.show()

# %% [markdown]
# # Modularity - Layer 2

# %%
# Correlation matrix for every epoch of Hidden Layer 1
corr_mat_epoch_l2 = []
for n in range(numEpochs):
    df = pd.DataFrame(cbk4.weights[n], index = index_neuron , columns = weights_neuron)
    df = df.transpose() 
    df = df.corr()
    df = df.mask(np.tril(np.ones(df.shape)).astype(np.bool_), 0) 
    corr_mat_epoch_l2.append(df)

# %%
# finding modularity for each matrix 
modularity_layer2 = []
communities_layer2 = []
for n in range(numEpochs):
    cor_mat = corr_mat_epoch_l2[n]
        # creating edge list 
    links = cor_mat.stack().reset_index()
    links.columns = ['Neuron A', 'Neuron B', 'Value'] 
    # drop the rows with 0 in Value 
    rows_zero = links.loc[links['Value'] == 0.0]
    links = links.drop(rows_zero.index)

    # save values with correlation more than 0.2
    links_filtered=links.loc[ (links['Value'] > abs(0.2)) ]

    # make the graph 
    G=nx.from_pandas_edgelist(links_filtered, 'Neuron A', 'Neuron B')
    pos = nx.spring_layout(G) 
    
    # calculate modularity 
    # Detect communities using Louvain algorithm
    partition = community_louvain.best_partition(G)
    
    # list of communities
    new_dict = {}
    for key, value in partition.items():
        new_dict.setdefault(value, []).append(key)
    # Convert the dictionary of lists into a list of lists
    result = list(new_dict.values())
    
    communities_layer2.append(len(result))

    modularity = community_louvain.modularity(partition, G)
    
    modularity_layer2.append(modularity)

# %%
plt.figure(figsize=(12,10))
plt.plot(modularity_layer2)
plt.xlabel("Epoch", fontsize = 20)
plt.ylabel("Modularity", fontsize = 20)
plt.title("Modularity of Layer 2", fontsize = 20)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.plot(communities_layer2)
plt.xlabel("Epoch", fontsize = 20)
plt.ylabel("Communities", fontsize = 20)
plt.title("Communities in Layer 2", fontsize = 20)
plt.grid(True)
plt.show()

# %% [markdown]
# # Modularity Function - Change Over Time - Layer 3

# %%
# Correlation matrix for every epoch of Hidden Layer 1
corr_mat_epoch_l3 = []
for n in range(numEpochs):
    df = pd.DataFrame(cbk6.weights[n], index = index_neuron , columns = weights_neuron)
    df = df.transpose()
    df = df.corr()
    df = df.mask(np.tril(np.ones(df.shape)).astype(np.bool_), 0) 
    corr_mat_epoch_l3.append(df)

# %%
# finding modularity for each matrix 
modularity_layer3 = []
communities_layer3 = []
for n in range(numEpochs):
    cor_mat = corr_mat_epoch_l3[n]
        # creating edge list 
    links = cor_mat.stack().reset_index()
    links.columns = ['Neuron A', 'Neuron B', 'Value'] 
    # drop the rows with 0 in Value 
    rows_zero = links.loc[links['Value'] == 0.0]
    links = links.drop(rows_zero.index)

    # save values with correlation more than 0.2
    links_filtered=links.loc[ (links['Value'] > abs(0.2)) ]

    # make the graph 
    G=nx.from_pandas_edgelist(links_filtered, 'Neuron A', 'Neuron B')
    pos = nx.spring_layout(G) 

    # calculate modularity 
    # Detect communities using Louvain algorithm
    partition = community_louvain.best_partition(G)
    
    # list of communities
    new_dict = {}
    for key, value in partition.items():
        new_dict.setdefault(value, []).append(key)
    # Convert the dictionary of lists into a list of lists
    result = list(new_dict.values())
    
    communities_layer3.append(len(result))

    modularity = community_louvain.modularity(partition, G)
    
    modularity_layer3.append(modularity)

# %%
plt.figure(figsize=(12,10))
plt.plot(modularity_layer3)
plt.xlabel("Epoch", fontsize = 20)
plt.ylabel("Modularity", fontsize = 20)
plt.title("Modularity of Layer 3", fontsize = 20)
#ax2 = plt.twiny()
#ax2.plot(pd.Series(np.random.uniform(10, 20, size=10)), color='r')
#ax2.grid(None)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.plot(communities_layer3)
plt.xlabel("Epoch", fontsize = 20)
plt.ylabel("Communities", fontsize = 20)
plt.title("Communities in Layer 3", fontsize = 20)
plt.grid(True)
plt.show()

# %% [markdown]
# # Modularity Function - Change over time - all layers

# %%
plt.figure(figsize=(12,10))
plt.plot(modularity_layer1)
plt.plot(modularity_layer2)
plt.plot(modularity_layer3)
plt.xlabel("Epoch", fontsize = 20)
plt.ylabel("Modularity", fontsize = 20)
plt.title("Modularity of Layers 1, 2 and 3", fontsize = 20)
plt.legend(['L1', 'L2', 'L3'])
plt.grid(True)
plt.show()

# %% [markdown]
# # Number of Communities for layers in every epoch

# %%
plt.figure(figsize=(12, 10))
plt.scatter(range(100), communities_layer1)
plt.scatter(range(100), communities_layer2)
plt.scatter(range(100), communities_layer3)
plt.xlabel('Number Epoch', fontsize = 18)
plt.ylabel('Number of Communities', fontsize = 18)
plt.title('Number of Communities over epochs', fontsize= 20)
plt.legend(['L1', 'L2', 'L3'])
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 10))
plt.plot(range(100), communities_layer1)
plt.plot(range(100), communities_layer2)
plt.plot(range(100), communities_layer3)
plt.xlabel('Number Epoch', fontsize = 18)
plt.ylabel('Number of Communities', fontsize = 18)
plt.title('Number of Communities over epochs', fontsize= 20)
plt.legend(['L1', 'L2', 'L3'])
plt.grid(True)
plt.show()

# %% [markdown]
# # Mann Whitney Test

# %%
from scipy.stats import mannwhitneyu

# %%
statistic_12, pvalue_12 = mannwhitneyu(modularity_layer1[:5], modularity_layer2[:5], alternative = 'two-sided')
if pvalue_12 < 0.05:
    print("Reject Null Hypothesis \nThat is: The means are equal")
else:
    print("Dont Accept Null Hypothesis \nThat is: The means are not equal")
print("Pvalue: " + str(pvalue_12))
# Out:
# Dont Accept Null Hypothesis
# That is: The means are not equal
# Pvalue: 0.6904761904761905

# %%
statistic_23, pvalue_23 = mannwhitneyu(modularity_layer2, modularity_layer3, alternative = 'two-sided')
if pvalue_23 < 0.05:
    print("Reject Null Hypothesis \nThat is: The means are equal")
else:
    print("Dont Accept Null Hypothesis \nThat is: The means are not equal")
print("Pvalue: " + str(pvalue_23))
# Out:
# Reject Null Hypothesis
# That is: The means are equal
# Pvalue: 4.487863126052552e-12

# %%
statistic_31, pvalue_31 = mannwhitneyu(modularity_layer3, modularity_layer1, alternative = 'two-sided')
if pvalue_31 < 0.05:
    print("Reject Null Hypothesis \nThat is: The means are equal")
else:
    print("Dont Accept Null Hypothesis \nThat is: The means are not equal")
print("Pvalue: " + str(pvalue_31))
# Out:
# Reject Null Hypothesis
# That is: The means are equal
# Pvalue: 1.5565033867829217e-11

# %% [markdown]
# # Statistical Test of Modularities btw L1 and L2

# %%
# Man - Whitney Test 
# Threshold - 0.5
